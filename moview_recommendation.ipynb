# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('movie1.csv')
df.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
df.tail(10)
# Out:
#       adult belongs_to_collection  budget  \
# 1100  False                   NaN  400000
# 1101  False                   NaN       0
# 1102  False                   NaN       0
# 1103  False                   NaN       0
# 1104  False                   NaN       0
# 1105  False                   NaN  500000
# 1106  False                   NaN       0
# 1107  False                   NaN       0
# 1108  False                   NaN       0
# 1109  False                   NaN       0
#
#                                                  genres  \
# 1100  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 1101  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 1102                                                 []
# 1103                      [{'id': 18, 'name': 'Drama'}]
# 1104                      [{'id': 18, 'name': 'Drama'}]
# 1105  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1106                [{'id': 99, 'name': 'Documentary'}]
# ...

# %%
import seaborn as sns
sns.pairplot(df)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
df.shape
# Out:
# (1110, 24)

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  1.110000e+03    1110.000000  1110.000000  1.110000e+03  1105.000000
# mean   9.906667e+06   38240.970270     6.125317  3.478202e+07   104.116742
# std    1.894356e+07   59656.633907     7.375777  9.712548e+07    22.445303
# min    0.000000e+00       5.000000     0.000082  0.000000e+00     0.000000
# 25%    0.000000e+00    9099.250000     1.317025  0.000000e+00    93.000000
# 50%    0.000000e+00   15308.000000     5.043478  0.000000e+00   102.000000
# 75%    1.200000e+07   41589.500000     9.170414  1.755754e+07   114.000000
# max    1.750000e+08  427043.000000   140.950236  9.201000e+08   238.000000
#
#        vote_average   vote_count
# count   1110.000000  1110.000000
# mean       5.994505   295.816216
# std        1.648361   809.648173
# min        0.000000     0.000000
# 25%        5.400000    10.000000
# 50%        6.300000    49.500000
# 75%        7.000000   199.000000
# ...

# %%
# finding the average revenue
a = df
a = a.groupby('title')['revenue'].mean()
a
# Out:
# title
# 1-900                                  0.0
# 2 Days in the Valley                   0.0
# 20,000 Leagues Under the Sea    28200000.0
# 2001: A Space Odyssey           68700000.0
# 301, 302                               0.0
#                                    ...
# Wolf                                   0.0
# Wyatt Earp                      25052000.0
# Yankee Zulu                            0.0
# Yes, Madam                             0.0
# À la mode                              0.0
# Name: revenue, Length: 1108, dtype: float64

# %%
# avg budget
a = df
a = a.groupby('title')['budget'].mean()
a
# Out:
# title
# 1-900                                  0.0
# 2 Days in the Valley                   0.0
# 20,000 Leagues Under the Sea     5000000.0
# 2001: A Space Odyssey           10500000.0
# 301, 302                               0.0
#                                    ...
# Wolf                                   0.0
# Wyatt Earp                      63000000.0
# Yankee Zulu                            0.0
# Yes, Madam                             0.0
# À la mode                              0.0
# Name: budget, Length: 1108, dtype: float64

# %%
# avg popularity
a = df
a = a.groupby('title')['popularity'].mean()
a
# Out:
# title
# 1-900                            0.062128
# 2 Days in the Valley             4.989276
# 20,000 Leagues Under the Sea     8.722406
# 2001: A Space Odyssey           22.494622
# 301, 302                         0.396626
#                                   ...
# Wolf                            14.063845
# Wyatt Earp                       9.277147
# Yankee Zulu                      1.558066
# Yes, Madam                       1.060097
# À la mode                        0.000082
# Name: popularity, Length: 1108, dtype: float64

# %%
# avg runtime
a = df
a = a.groupby('title')['runtime'].mean()
a
# Out:
# title
# 1-900                             0.0
# 2 Days in the Valley            104.0
# 20,000 Leagues Under the Sea    127.0
# 2001: A Space Odyssey           149.0
# 301, 302                        100.0
#                                 ...
# Wolf                            125.0
# Wyatt Earp                      191.0
# Yankee Zulu                     100.0
# Yes, Madam                       93.0
# À la mode                        82.0
# Name: runtime, Length: 1108, dtype: float64

# %%
# avg count
a = df
a = a.groupby('title')['revenue'].count()
a
# Out:
# title
# 1-900                           1
# 2 Days in the Valley            1
# 20,000 Leagues Under the Sea    1
# 2001: A Space Odyssey           1
# 301, 302                        1
#                                ..
# Wolf                            1
# Wyatt Earp                      1
# Yankee Zulu                     1
# Yes, Madam                      1
# À la mode                       1
# Name: revenue, Length: 1108, dtype: int64

# %%
# avg budget
a = df
a = a.groupby('title')['budget'].count()
a
# Out:
# title
# 1-900                           1
# 2 Days in the Valley            1
# 20,000 Leagues Under the Sea    1
# 2001: A Space Odyssey           1
# 301, 302                        1
#                                ..
# Wolf                            1
# Wyatt Earp                      1
# Yankee Zulu                     1
# Yes, Madam                      1
# À la mode                       1
# Name: budget, Length: 1108, dtype: int64

# %%
# avg popularity
a = df
a = a.groupby('title')['popularity'].count()
a
# Out:
# title
# 1-900                           1
# 2 Days in the Valley            1
# 20,000 Leagues Under the Sea    1
# 2001: A Space Odyssey           1
# 301, 302                        1
#                                ..
# Wolf                            1
# Wyatt Earp                      1
# Yankee Zulu                     1
# Yes, Madam                      1
# À la mode                       1
# Name: popularity, Length: 1108, dtype: int64

# %%
# avg runtime
a = df
a = a.groupby('title')['budget'].count()
a
# Out:
# title
# 1-900                           1
# 2 Days in the Valley            1
# 20,000 Leagues Under the Sea    1
# 2001: A Space Odyssey           1
# 301, 302                        1
#                                ..
# Wolf                            1
# Wyatt Earp                      1
# Yankee Zulu                     1
# Yes, Madam                      1
# À la mode                       1
# Name: budget, Length: 1108, dtype: int64

# %%
sns.relplot(data = df , x = 'revenue', y ='runtime', color = 'violet')

# %%
sns.lmplot(data=df, x="vote_average", y="popularity" )

# %%
sns.catplot(df , x="runtime" , color='darkgreen')

# %%
sns.catplot(df , x="vote_count" , color='teal')

# %%
df['adult'] = df['adult'].replace({'FALSE':1,'RUMORED':0})
df
df['status'] = df['status'].replace({'RELEASED':1})
df
# Out:
#       adult                              belongs_to_collection    budget  \
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1     False                                                NaN  65000000
# 2     False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3     False                                                NaN  16000000
# 4     False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...     ...                                                ...       ...
# 1105  False                                                NaN    500000
# 1106  False                                                NaN         0
# 1107  False                                                NaN         0
# 1108  False                                                NaN         0
# 1109  False                                                NaN         0
#
#                                                  genres  \
# ...

# %%
sns.jointplot(data = df , x = 'adult' , y='status', color = 'cadetblue')
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.jointplot(data = df , x = 'popularity' , y='revenue', color = 'teal')

# %%
sns.histplot(df , x="status" , color='springgreen')
# Out:
# <Axes: xlabel='status', ylabel='Count'>

# %%
sns.histplot(df , x="vote_average" , color='firebrick')
# Out:
# <Axes: xlabel='vote_average', ylabel='Count'>

# %%
sns.histplot(df , x="runtime" , color='slategray')
# Out:
# <Axes: xlabel='runtime', ylabel='Count'>

# %%
sns.histplot(df , x="vote_count" , color='lawngreen')
# Out:
# <Axes: xlabel='vote_count', ylabel='Count'>

# %%
sns.boxenplot(df , x="budget" , y='revenue', color = 'deeppink')
# Out:
# <Axes: xlabel='budget', ylabel='revenue'>
